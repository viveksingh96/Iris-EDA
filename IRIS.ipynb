# %% [markdown]
# # IRIS dataset
#
# iris dataset has 4 featues
# sepallength,sepalwidth,petallength,petalwidth

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
iris=pd.read_csv("iris1.csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#checking the shape for how many datapoints and features it has
iris.shape
# Out:
# (150, 5)

# %%
#checking the column/features
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#how many datapoints of each flower are present
#checking for balanced vs imbalanced dataset
iris['species'].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
#as we see it is balanced dataset as all species of iris flower have equal flowers
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.plot(kind='scatter',x='sepal_length',y='sepal_width')
#it cannot make much sense,color the species and then see

# %%
#2d scatter plot with color coding for each flower and class
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='species',size=4)\
.map(plt.scatter,'sepal_length','sepal_width')\
.add_legend()
#we noticed here blue are easily separated from green and orange by a line.
# we draw more 2d plot each of these combination of the featuesx to see the better result
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #Obsevations:
# 1.using sepal_length and sepal_width we can distinguish setosa from virginica and versicolor
# 2.separting virginica from versicolor is much harder here as they have much overlap.

# %%
#here we are using pairplot
sns.set_style('whitegrid')
sns.pairplot(iris,hue='species',size=3)
#petal_length and petal_width are two useful features to separate various flower types.
#setosa is eaily separble while virginica and versicolor have some overlap
#we can find lines and if else to build a simple model to classify the flower types.
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
#univariate analysis
iris_setosa=iris.loc[iris['species']=='setosa']
iris_virginica=iris.loc[iris['species']=='virginica']
iris_versicolor=iris.loc[iris['species']=='versicolor']

plt.plot(iris_setosa['petal_length'],np.zeros_like(iris_setosa['petal_length']),'o')
plt.plot(iris_versicolor['petal_length'],np.zeros_like(iris_versicolor['petal_length']),'o')
plt.plot(iris_virginica['petal_length'],np.zeros_like(iris_virginica['petal_length']),'o')
#very hard to make sense as points are overlapping a lot.

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='species',size=5)\
.map(sns.distplot,'petal_length')\
.add_legend()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='species',size=4)\
.map(sns.distplot,'petal_width')\
.add_legend()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='species',size=4)\
.map(sns.distplot,'sepal_length')\
.add_legend()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='species')\
.map(sns.distplot,'sepal_width')\
.add_legend()

# %%
#setosa
counts,bin_edges=np.histogram(iris_setosa['petal_length'],bins=10,density=True)
pdf=counts/sum(counts)
print(pdf)
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

#virginica
print("virginica>>>>>>>>>>>>")
counts,bin_edges=np.histogram(iris_virginica['petal_length'],bins=10,density=True)
pdf=counts/sum(counts)
print(counts)
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)


#versicolor
print("versicolor>>>>>>>>>>>")
counts,bin_edges=np.histogram(iris_versicolor['petal_length'],bins=10,density=True)
pdf=counts/sum(counts)
print(counts)
print(bin_edges)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# virginica>>>>>>>>>>>>
# [0.08333333 0.41666667 1.         0.33333333 0.75       0.66666667
#  0.41666667 0.16666667 0.08333333 0.25      ]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# versicolor>>>>>>>>>>>
# [0.0952381  0.19047619 0.28571429 0.19047619 0.76190476 0.66666667
#  0.57142857 0.95238095 0.66666667 0.38095238]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %%
#Mean, Variance, Std-deviation,  
print("Means:")
print(np.mean(iris_setosa["petal_length"]))
#Mean with an outlier.
print(np.mean(np.append(iris_setosa["petal_length"],50)));
print(np.mean(iris_virginica["petal_length"]))
print(np.mean(iris_versicolor["petal_length"]))

print("\nStd-dev:");
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))
# Out:
# Means:
# 1.464
# 2.4156862745098038
# 5.552
# 4.26
#
# Std-dev:
# 0.17176728442867115
# 0.5463478745268441
# 0.4651881339845204

# %% [markdown]
# # Median, Percentile, Quantile, IQR, MAD

# %%
#Median, Quantiles, Percentiles, IQR.
print("\nMedians:")
print(np.median(iris_setosa["petal_length"]))
#Median with an outlier
print(np.median(np.append(iris_setosa["petal_length"],50)));
print(np.median(iris_virginica["petal_length"]))
print(np.median(iris_versicolor["petal_length"]))


print("\nQuantiles:")
print(np.percentile(iris_setosa["petal_length"],np.arange(0, 100, 25)))
print(np.percentile(iris_virginica["petal_length"],np.arange(0, 100, 25)))
print(np.percentile(iris_versicolor["petal_length"], np.arange(0, 100, 25)))

print("\n90th Percentiles:")
print(np.percentile(iris_setosa["petal_length"],90))
print(np.percentile(iris_virginica["petal_length"],90))
print(np.percentile(iris_versicolor["petal_length"], 90))

from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(iris_setosa["petal_length"]))
print(robust.mad(iris_virginica["petal_length"]))
print(robust.mad(iris_versicolor["petal_length"]))
# Out:
# Medians:
# 1.5
# 1.5
# 5.55
# 4.35
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th Percentiles:
# 1.7
# 6.3100000000000005
# 4.8
#
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# # Box plot
# It is also used to detect outliers.

# %%
sns.boxplot(x='species',y='petal_length', data=iris)
plt.show()

# %% [markdown]
# # violin plot

# %%
sns.violinplot(x="species", y="petal_length", data=iris, size=8)
plt.show()

# %% [markdown]
# # contour plot:multivariate  probability density

# %%
sns.jointplot(x="petal_length", y="petal_width", data=iris_setosa, kind="kde");
plt.show();
